# %% [markdown]
# ## Problem 1: Unique Words in a Sentence
#
# ### Problem Statement
# Given a sentence, identify all unique words and display:
#
# - The count of unique words
# - The unique words themselves
#
# ### Hint
# - Split the sentence into individual words.
# - Convert the list of words into a set to remove duplicates.
# - Print both the set and its length.
#
# ### Input
# Enter sentence:  `python is easy and python is powerful`
#
#
# ### Real-Time Applications
# - Text analytics
# - Natural Language Processing (NLP) preprocessing
# - Search engine indexing
# - Chat analysis systems

# %%
# given Data
sentence = "python is easy and python is powerful"

# Now split the sentence in seperate words
words = sentence.split()
# remove duplicates from the list
unique = set(words)
# count of unique woeds
unique_count = len(unique)

# output
print("Count of unique word :", unique_count)
print("Unique world set :", unique)
# Out:
# Count of unique word : 5
# Unique world set : {'python', 'and', 'easy', 'is', 'powerful'}

# %% [markdown]
# ## Problem 2: Highest Salary from Employee Data
# ### Problem Statement
# - Store employee names and their salaries, and determine which employee has the - highest salary.
# ### Hint
# - Use a dictionary where the key is the employee name and the value is the salary.
# - Compare salary values to find the highest.
# ### Input Format
# - A dictionary where:
# Keys represent employee names
# Values represent employee salaries
# ### Example Input
# employees = {
#     "Ravi": 75000,
#     "Anita": 68000,
#     "Kiran": 72000
# }
#
#
#
# ### Real-Time Applications
# - HR management systems
# - Payroll analysis

# %%
# given Data
employees = {
    "Ravi": 75000,
    "Anita": 68000,
    "Kiran": 72000
}

# Initialize the values
highest_salary = 0
top_employee = ""

# Using .items() to get both Key name and Value salary
for name, salary in employees.items():
    if salary > highest_salary:
        highest_salary = salary
        top_employee = name

# Print the result outside the loop
print("Highest Salary:", top_employee, "-", highest_salary)
# Out:
# Highest Salary: Ravi - 75000

# %% [markdown]
# # Problem 3: Find Maximum and Minimum Values
#
# ## Problem Statement
# Find the maximum and minimum values from a list of numbers.
#
# ### Hint
# - Initialize both maximum and minimum with the first element of the list.
# - Use a loop to compare each element.
#
#
# ## Input Format
# A list of integers where each element represents a numeric value.
#
# ### Example Input
# ```python
# numbers = [45, 22, 89, 10, 66]
#
# ```
# ### Real-Time Applications
#  - Sales data analysis
#  - Temperature monitoring systems
#  - Performance metric evaluation

# %%
# Given Data
numbers = [45, 22, 89, 10, 66]

# Initialize both Min and Max
max = 0
min = 0

# Use loop to compaire the each element
for num in numbers:
    if num > max:
        max = num
        min = num
    elif num < min:
         min = num

print("List :", numbers)
print("Max :", max)
print("Min : ", min)
# Out:
# List : [45, 22, 89, 10, 66]
# Max : 89
# Min :  10

# %% [markdown]
# # Problem 4: Count Products Above a Price Threshold
#
# ## Problem Statement
# Count how many products have a price greater than 1000.
#
# ### Hint
# - Use a loop to compare each price with 1000.
#
#
# ## Input Format
# A list of integers where each element represents the price of a product.
#
# ### Example Input
# ```python
# prices = [450, 1200, 899, 1500, 300]
# ```
# ### Real-Time Applications
#  - E-commerce product filtering
#  - Budget analysis

# %%
# given data
prices = [450, 1200, 899, 1500, 300]

# Initialize the values
count = 0

# Use Loops to compare price
for price in prices:
    if price > 1000:
        count +=1

print("Products price above 1000 :", count)
# Out:
# Products price above 1000 : 2

# %% [markdown]
# # Problem 5: Calculate Attendance Percentage
#
# ## Problem Statement
# Calculate the attendance percentage from a list containing "P" (Present) and "A" (Absent).
#
# ### Hint
# - Count the number of "P" values.
# - Divide by the total number of days.
#
#
# ## Input Format
# A list where each element is either:
# - `"P"` for Present
# - `"A"` for Absent
#
# ### Example Input
# ```python
# attendance = ["P", "P", "A", "P", "P"]
# ```
# ### Real-Time Applications
#  - Internship tracking systems
#  - HR attendance management systems

# %%
# Given Data
attendance = ["P", "P", "A", "P", "P"]

# initialize the values
P_count = 0
D_count = len(attendance)

# Use loop to cheak attendence is intern or student is present or absent
for status in attendance:
  if status == "P":
     P_count +=1
# Calculating the attendance percentage

attendence_percentage = (P_count / D_count) * 100

print("Attendance Percentage : ", attendence_percentage)
# Out:
# Attendance Percentage :  80.0

# %% [markdown]
# # Problem 6: Remove Duplicate Phone Numbers
#
# ## Problem Statement
# You are given a list of phone numbers that may contain duplicates.
# Write a Python program to remove duplicate phone numbers and display only the unique phone numbers.
#
# ### Hint
# - Convert the list into a set.
# - Sets automatically remove duplicate values.
#
#
# ## Input Format
# A list of integers where each integer represents a phone number.
#
# ### Example Input
# ```python
# phone_numbers = [9876543210, 9123456789, 9876543210]
# ```
# ### Real-Time Applications
#  - Contact management applications
#  - Customer Relationship Management (CRM) systems
#  - Marketing databases

# %%
# Given Data
phone_numbers = [9876543210, 9123456789, 9876543210]

# remove duplicates from the list
unique = set(phone_numbers)

# output
print("Unique phone numbers :", unique)
# Out:
# Unique phone numbers : {9876543210, 9123456789}

# %% [markdown]
# # Problem 7: Count Character Frequency
#
# ## Problem Statement
# Count how many times each character appears in a given string.
#
# ### Hint
# - Use a dictionary.
# - Increment the count for each character occurrence.
#
#
# ## Example Input
# ```python
# text = "python"
# ```
#
# ### Real-Time Applications
#  - Text analysis
#  - Password strength validation

# %%
# Data is not provided so i take it myself to get expected output
str = "pythonp"

# Initialize an empty dictionary to store counts
char = {}

# loop to solve
for i in str:
     if i in char:
         char[i] += 1
     else:
       char[i] = 1
print(char)
# Out:
# {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %% [markdown]
# # Problem 8: Convert List to Tuple
#
# ## Problem Statement
# Convert a list into a tuple and display it.
#
# ### Hint
# - Use the `tuple()` function.
#
#
# ## Example Input
# ```python
# numbers = [10, 20, 30]
# ```
#  ### Real-Time Applications
#  - Making data read-only
#  - Configuration settings storage

# %%
# Data is not provided so i take it myself to get expected output
List = [10, 20, 30]

# Now make it tuple using tuple()
Tuple = tuple(List)

print(Tuple)
# Out:
# (10, 20, 30)

# %% [markdown]
# ## Problem 9: Check if a Key Exists in a Dictionary
# ## Problem Statement
#  - Check whether a specific key exists in a dictionary.
# ##Hint
#  - Use the `in` keyword.
#  - Expected Output
#  - Employee exists
#
# ## Real-Time Applications
#  - User validation systems
#  -Configuration verification

# %%
# Data is not provided so i take it myself to get expected output
employees = {
    "Employee" : "Mangesh",
    "ID" : 123
}

## Check if a key exists using if keyword
if "Employee" in employees:
     print("Employee exists")
else:
     print("Employee does not exist")
# Out:
# Employee exists

# %% [markdown]
# ## Problem 10: Calculate Average Marks
# ### Problem Statement
#  - Calculate the average marks of a student from a list of marks.
#
# ### Hint
#  - Calculate the sum of all values.
#  - Divide by the total number of marks.
#
# ### Real-Time Applications
#  - Student performance evaluation
#  - Result processing systems
#
# ### Real-Time Applications
#  - Student performance evaluation
#  - Result processing systems

# %%
# Data is not provided so i take it myself to get expected output
# List of marks
marks = [80, 70, 65, 75]

#  Calculate sum
total = sum(marks)

# find total subjects
sub = len(marks)

# Step 3: Calculate average
average = total / sub

# Step 4: Print result
print("Average Marks:", average)
# Out:
# Average Marks: 72.5
